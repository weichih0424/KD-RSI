# %%
import os
import pandas as pd
inPath = os.path.join(".","input")
outPath =os.path.join(".","output")

# %%
dbPath = inPath + "/寶齡富錦(1760).xlsx"
data= pd.read_excel(dbPath)
print(data)
# Out:
#             時間     開盤價     最高價     最低價     收盤價    SMA5   SMA10   SMA20  \
# 0   2017-01-03   74.89   74.89   73.50   73.88   74.38   74.25   74.88
# 1   2017-01-04   73.51   76.58   73.50   76.34   74.81   74.51   74.83
# 2   2017-01-05   76.34   79.69   75.98   78.49   75.66   75.04   74.93
# 3   2017-01-06   78.00   79.29   77.77   78.30   76.32   75.47   75.09
# 4   2017-01-09   79.00   80.89   77.96   79.35   77.27   75.91   75.24
# ..         ...     ...     ...     ...     ...     ...     ...     ...
# 949 2020-11-19  102.00  103.50  101.00  102.00  102.50  105.85  108.45
# 950 2020-11-20  101.00  102.00  100.00  100.50  101.80  104.55  107.78
# 951 2020-11-23  101.50  101.50   98.70   99.00  100.80  102.85  107.13
# 952 2020-11-24  100.00  101.00   96.80   97.00  100.00  101.85  106.38
# 953 2020-11-25   98.00  101.00   97.50   97.90   99.28  101.09  105.75
#
#       SMA60  SMA120  EMA-SMA   RSI 6  RSI 12  K(9,3)  D(9,3)
# 0     79.78   88.52     0.73  0.3767  0.3804  0.4888  0.4676
# 1     79.64   88.10     0.88  0.6657  0.5298  0.6372  0.5241
# 2     79.53   87.70     1.10  0.7751  0.6177  0.6935  0.5806
# 3     79.41   87.30     1.19  0.7491  0.6068  0.7208  0.6273
# 4     79.33   86.86     1.39  0.7947  0.6447  0.7444  0.6664
# ..      ...     ...      ...     ...     ...     ...     ...
# 949  120.14  123.25    -0.23  0.2920  0.3347  0.1804  0.2507
# 950  119.80  122.85    -0.29  0.2453  0.3128  0.1457  0.2157
# 951  119.41  122.50    -0.46  0.2059  0.2920  0.1074  0.1796
# 952  118.78  122.19    -0.64  0.1637  0.2662  0.0784  0.1459
# 953  118.17  121.89    -0.76  0.2470  0.2967  0.0944  0.1287
#
# [954 rows x 15 columns]

# %%
KD = []
K = data['K(9,3)']
D = data['D(9,3)']

KD.append('NaN')
x=0

for i in range(1,len(data)):
    x = K[i-1] - D[i-1]
    y = K[i] - D[i]
    if x > 0 and y < 0:
        KD.append('死亡交叉')
    elif x < 0 and y > 0:
        KD.append('黃金交叉')
    else:
        KD.append('NaN')

data['KD'] = KD
print(data)
# Out:
#             時間     開盤價     最高價     最低價     收盤價    SMA5   SMA10   SMA20  \
# 0   2017-01-03   74.89   74.89   73.50   73.88   74.38   74.25   74.88
# 1   2017-01-04   73.51   76.58   73.50   76.34   74.81   74.51   74.83
# 2   2017-01-05   76.34   79.69   75.98   78.49   75.66   75.04   74.93
# 3   2017-01-06   78.00   79.29   77.77   78.30   76.32   75.47   75.09
# 4   2017-01-09   79.00   80.89   77.96   79.35   77.27   75.91   75.24
# ..         ...     ...     ...     ...     ...     ...     ...     ...
# 949 2020-11-19  102.00  103.50  101.00  102.00  102.50  105.85  108.45
# 950 2020-11-20  101.00  102.00  100.00  100.50  101.80  104.55  107.78
# 951 2020-11-23  101.50  101.50   98.70   99.00  100.80  102.85  107.13
# 952 2020-11-24  100.00  101.00   96.80   97.00  100.00  101.85  106.38
# 953 2020-11-25   98.00  101.00   97.50   97.90   99.28  101.09  105.75
#
#       SMA60  SMA120  EMA-SMA   RSI 6  RSI 12  K(9,3)  D(9,3)   KD
# 0     79.78   88.52     0.73  0.3767  0.3804  0.4888  0.4676  NaN
# 1     79.64   88.10     0.88  0.6657  0.5298  0.6372  0.5241  NaN
# 2     79.53   87.70     1.10  0.7751  0.6177  0.6935  0.5806  NaN
# 3     79.41   87.30     1.19  0.7491  0.6068  0.7208  0.6273  NaN
# 4     79.33   86.86     1.39  0.7947  0.6447  0.7444  0.6664  NaN
# ..      ...     ...      ...     ...     ...     ...     ...  ...
# 949  120.14  123.25    -0.23  0.2920  0.3347  0.1804  0.2507  NaN
# 950  119.80  122.85    -0.29  0.2453  0.3128  0.1457  0.2157  NaN
# 951  119.41  122.50    -0.46  0.2059  0.2920  0.1074  0.1796  NaN
# 952  118.78  122.19    -0.64  0.1637  0.2662  0.0784  0.1459  NaN
# 953  118.17  121.89    -0.76  0.2470  0.2967  0.0944  0.1287  NaN
#
# [954 rows x 16 columns]

# %%
data2 = data.loc[(data['KD']=='死亡交叉') | (data['KD']=='黃金交叉')]
data = data2['時間'].astype(str)
data2['時間'] = data
data2 = data2.reset_index()
data2 =data2.drop(columns=['index'])
print(data2)



SMA60 = data2['SMA60']
close = data2['收盤價']
KD = data2['KD']

BUY = []
for i in range(len(data2)):
    x = close[i] - SMA60[i]
    if x > 0 and KD[i]=='黃金交叉':
        BUY.append('買')
    elif x < 0 and KD[i]=='死亡交叉':
        BUY.append('賣')
    else:
        BUY.append('再考慮')

print(BUY)
# Out:
#              時間     開盤價     最高價     最低價     收盤價    SMA5   SMA10   SMA20  \
# 0    2017-01-17   79.17   79.19   77.99   78.28   78.97   78.68   76.46
# 1    2017-01-24   80.00   80.57   79.02   79.73   78.85   78.91   77.65
# 2    2017-02-02   79.74   79.74   77.31   78.30   78.84   78.90   77.86
# 3    2017-02-15   77.00   77.00   76.25   76.69   76.43   76.96   77.94
# 4    2017-02-22   78.00   78.00   76.21   77.16   78.81   77.78   77.89
# ..          ...     ...     ...     ...     ...     ...     ...     ...
# 162  2020-10-07  126.00  126.50  123.00  124.00  124.80  126.65  128.88
# 163  2020-10-23  113.50  115.00  113.50  114.00  113.60  114.60  120.30
# 164  2020-10-28  113.00  113.50  110.00  110.50  112.30  112.95  117.95
# 165  2020-11-02  105.00  109.00  103.00  107.50  108.90  111.15  115.03
# 166  2020-11-11  107.00  108.50  104.00  105.50  111.30  110.40  111.68
#
#       SMA60  SMA120  EMA-SMA   RSI 6  RSI 12  K(9,3)  D(9,3)    KD
# 0     78.89   84.18  1.39000  0.5129  0.5413  0.6749  0.7271  死亡交叉
# 1     78.44   82.39  0.57000  0.6392  0.6002  0.5074  0.4935  黃金交叉
# 2     78.41   82.21  0.34000  0.4634  0.5144  0.4236  0.4702  死亡交叉
# 3     77.83   80.69 -0.85000  0.4086  0.4455  0.2748  0.2568  黃金交叉
# 4     77.25   79.96 -0.00079  0.3843  0.4548  0.5081  0.5625  死亡交叉
# ..      ...     ...      ...     ...     ...     ...     ...   ...
# 162  124.49  128.70 -1.08000  0.4182  0.4535  0.3741  0.3802  死亡交叉
# 163  123.93  129.67 -1.15000  0.3759  0.3883  0.1803  0.1571  黃金交叉
# 164  123.68  128.98 -0.83000  0.2488  0.3382  0.1328  0.1511  死亡交叉
# 165  122.94  128.05 -0.49000  0.3286  0.3432  0.1864  0.1483  黃金交叉
# 166  122.08  126.01  1.11000  0.3150  0.3628  0.4650  0.5587  死亡交叉
#
# [167 rows x 16 columns]
# ['賣', '買', '賣', '再考慮', '賣', '再考慮', '賣', '買', '再考慮', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '再考慮', '再考慮', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '買', '再考慮', '買', '再考慮', '買', '再考慮', '買', '再考慮', '買', '賣', '再考慮', '賣', '再考慮', '再考慮', '買', '再考慮', '買', '再考慮', '買', '再考慮', '買', '再考慮', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '買', '賣', '買', '再考慮', '買', '再考慮', '買', '再考慮', '買', '再考慮', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '買', '再考慮', '買', '再考慮', '買', '再考慮', '買', '再考慮', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '買', '賣', '買', '再考慮', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '再考慮', '再考慮', '買', '再考慮', '買', '賣', '買', '再考慮', '再考慮', '賣', '再考慮', '賣', '再考慮', '賣', '再考慮', '再考慮', '買', '再考慮', '買', '再考慮', '買', '再考慮', '買', '再考慮', '買', '再考慮', '買', '再考慮', '買', '再考慮', '買', '再考慮', '再考慮', '賣', '再考慮', '賣', '買', '再考慮', '買', '再考慮', '買', '賣', '買', '賣', '買', '賣', '再考慮', '賣', '再考慮', '賣']

# %%
dict1 = {"日期": data2['時間'],  
        "K值": data2['K(9,3)'],
        "D值": data2['D(9,3)'],
        "黃金/死亡交叉" : data2['KD'],
        "RSI":data2['RSI 6'],
        "當天收盤股價": data2['收盤價'],
        "季線" : data2['SMA60'],
        "買或賣" : BUY
       }
df=pd.DataFrame(dict1)
print(df)
df.to_excel(outPath+"/寶齡富錦(1760).xlsx",encoding="utf8")
# Out:
#              日期      K值      D值 黃金/死亡交叉     RSI  當天收盤股價      季線  買或賣
# 0    2017-01-17  0.6749  0.7271    死亡交叉  0.5129   78.28   78.89    賣
# 1    2017-01-24  0.5074  0.4935    黃金交叉  0.6392   79.73   78.44    買
# 2    2017-02-02  0.4236  0.4702    死亡交叉  0.4634   78.30   78.41    賣
# 3    2017-02-15  0.2748  0.2568    黃金交叉  0.4086   76.69   77.83  再考慮
# 4    2017-02-22  0.5081  0.5625    死亡交叉  0.3843   77.16   77.25    賣
# ..          ...     ...     ...     ...     ...     ...     ...  ...
# 162  2020-10-07  0.3741  0.3802    死亡交叉  0.4182  124.00  124.49    賣
# 163  2020-10-23  0.1803  0.1571    黃金交叉  0.3759  114.00  123.93  再考慮
# 164  2020-10-28  0.1328  0.1511    死亡交叉  0.2488  110.50  123.68    賣
# 165  2020-11-02  0.1864  0.1483    黃金交叉  0.3286  107.50  122.94  再考慮
# 166  2020-11-11  0.4650  0.5587    死亡交叉  0.3150  105.50  122.08    賣
#
# [167 rows x 8 columns]
